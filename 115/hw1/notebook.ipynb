# %%
from lib import *

Simulator(mu=10, limit=7200, verbose=False).start().analyze()
# Out:
# --- Stats
# trains served: 8613
# average time train is in system: 5.99h
# max time train is in system: 32.68h
# total dock idle: 0.57%
# total dock busy: 39.03%
# total dock hogged-out: 0.43%
# maximum # trains in queue: 5 trains
# average time in queue: 1.72h
